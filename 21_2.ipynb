# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas27092004/Data-Handling/blob/main/21_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
df=pd.read_csv('/content/Datasets/BL-Flickr-Images-Book.csv')
df.head()
# Out:
#    Identifier             Edition Statement       Place of Publication  \
# 0         206                           NaN                     London
# 1         216                           NaN  London\t Virtue & Yorston
# 2         218                           NaN                     London
# 3         472                           NaN                     London
# 4         480  A new edition, revised, etc.                     London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of â€œAll for ...  A., A. A.
# ...

# %%
df=pd.read_csv('/content/Datasets/BL-Flickr-Images-Book.csv')
df.tail()
# Out:
#       Identifier Edition Statement Place of Publication Date of Publication  \
# 2359     1039585               NaN         Boston, Mass              [1855]
# 2360     1040079               NaN              Alnwick              [1868]
# 2361     1040107               NaN               London                1691
# 2362     1040305               NaN            Edinburgh                1883
# 2363     1040619               NaN               London                1869
#
#               Publisher                                              Title  \
# 2359                NaN  History of the Capital of Asia and the Turks: ...
# 2360                NaN  Burgh-on-the-Sands, Cumberland. Death of King ...
# 2361       J. Hindmarsh  King Edward the Third, with the fall of Mortim...
# 2362  Privately printed  The County of Angus, 1678. (Translated from th...
# 2363                NaN  Susan Fielding. [A novel.] By the Author of â€...
#
# ...

# %%
df.dtypes
# Out:
# Identifier                                      int64
# Edition Statement                              object
# Place of Publication                           object
# Date of Publication                            object
# Publisher                                      object
# Title                                          object
# Author                                         object
# Contributors                                   object
# Corporate Author                              float64
# Corporate Contributors                        float64
# Former owner                                  float64
# Engraver                                      float64
# Issuance type                                  object
# Flickr URL                                     object
# Shelfmarks\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t     object
# dtype: object

# %%
to_drop=['Title']
df.drop(to_drop, inplace=True,axis=1)
df.head()
# Out:
#                  Place of Publication Date of Publication  \
# Identifier
# 206                            London         1879 [1878]
# 216         London\t Virtue & Yorston                1868
# 218                            London                1869
# 472                            London                1851
# 480                            London                1857
#
#                         Publisher     Author  \
# Identifier
# 206              S. Tinsley & Co.      A. A.
# 216                  Virtue & Co.  A., A. A.
# 218         Bradbury, Evans & Co.  A., A. A.
# 472                 James Darling  A., E. S.
# 480          Wertheim & Macintosh  A., E. S.
#
#                                             Contributors  Corporate Author  \
# Identifier
# 206                                      FORBES, Walter.               NaN
# 216         BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2364 entries, 206 to 1040619
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Place of Publication        2364 non-null   object
#  1   Date of Publication         2338 non-null   object
#  2   Publisher                   1606 non-null   object
#  3   Title                       2364 non-null   object
#  4   Author                      1855 non-null   object
#  5   Contributors                2364 non-null   object
#  6   Corporate Author            0 non-null      float64
#  7   Corporate Contributors      0 non-null      float64
#  8   Former owner                0 non-null      float64
#  9   Engraver                    0 non-null      float64
#  10  Issuance type               2364 non-null   object
#  11  Flickr URL                  2364 non-null   object
#  12  Shelfmarks																  2364 non-null   object
# ...

# %%
df.set_index('Identifier',inplace=True)
df.head()
# Out:
#                  Place of Publication Date of Publication  \
# Identifier
# 206                            London         1879 [1878]
# 216         London\t Virtue & Yorston                1868
# 218                            London                1869
# 472                            London                1851
# 480                            London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of â€œAll for ...  A., A. A.
# ...

# %%
unwanted_characters=['[',',','-']
def clean_dates(item):
  dop=str(item.loc['Date of Publication'])
  if dop=='nan'or dop[0]=='[':
    return np.NaN
    for character in unwanted_characters:
      if character in dop:
        character_index=dop.find(character)
        dop=drop[:characater_index]
  return dop
df['Date of Publication']=df.apply(clean_dates,axis=1)
